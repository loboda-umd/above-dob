# %% [markdown]
# # Visualization Test of Fire Perimeters

# %%
import pandas as pd
import geopandas as gpd

# %%
alaska_filename = '/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/DAAC_Update_2023/Fire_Perimeters/ALFD_1940_2022/ALFD_1940_2022.shp'
canada_filename = '/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/DAAC_Update_2023/Fire_Perimeters/NBAC_1986_2022/nbac_1986_to_2022_20230630.shp'

# %%
alaska_gdf = gpd.read_file(alaska_filename)
alaska_gdf.head()
# Out:
#    OBJECTID                               NAME RECORDNUMB     ACRES AFSNUMBER  \
# 0         1                        2022 MID Rx       2200   1467.14      None
# 1         2              2022 MID Fall Pile Rx     220004     86.99      None
# 2         3  2022 Oklahoma and Stuart Creek Rx     220003  66663.10      None
# 3         4                           Borealis        647      0.20      P0LV
# 4         5                          Tetthajik        663    122.85      P2L6
#
#   DOFNUMBER USFSNUMBER ADDNUMBER  PERIMETERD LATESTPERI  ... UPDATEUSER  \
# 0  73234001       None      2008  2022-11-22        Yes  ...   dmgriggs
# 1      None       None     108.3  2022-11-10        Yes  ...   dmgriggs
# 2      None       None     66662  2022-11-01        Yes  ...   dmgriggs
# 3    213647     PNP0LV       0.5  2022-10-31        Yes  ...  jljenkins
# 4      None     PDP2L6      None  2022-09-21        Yes  ...  jljenkins
#
# ...

# %%
canada_gdf = gpd.read_file(canada_filename)
canada_gdf.head()
# Out:
#      YEAR  NFIREID  BASRC  FIREMAPS  FIREMAPM  FIRECAUS  BURNCLAS SDATE EDATE  \
# 0  1986.0    208.0    1.0       9.0       7.0       2.0       4.0  None  None
# 1  1986.0     31.0    1.0       9.0       7.0       4.0       4.0  None  None
# 2  1986.0    159.0    3.0       0.0       2.0       4.0       4.0  None  None
# 3  1986.0    102.0    3.0       0.0       2.0       4.0       4.0  None  None
# 4  1986.0     13.0    1.0       9.0       7.0       2.0       4.0  None  None
#
#       AFSDATE AFEDATE     CAPDATE      POLY_HA       ADJ_HA  ADJ_FLAG AGENCY  \
# 0  1986-07-10    None  1986-09-12  3408.092664  3408.092664       0.0     NT
# 1  1986-05-14    None  1986-06-20  2767.768044  2767.768044       0.0     NB
# 2  1986-05-28    None        None    49.268235    53.316641       2.0     BC
# 3  1986-10-20    None        None     6.743968     7.880180       2.0     BC
# 4  1986-05-27    None  1986-07-30  1882.734463  1882.734463       0.0     QC
#
#    BT_GID           VERSION  \
# ...

# %%
canada_gdf.plot()
# Out:
# <AxesSubplot: >

# %%
alaska_gdf.columns
# Out:
# Index(['OBJECTID', 'NAME', 'RECORDNUMB', 'ACRES', 'AFSNUMBER', 'DOFNUMBER',
#        'USFSNUMBER', 'ADDNUMBER', 'PERIMETERD', 'LATESTPERI', 'SOURCE',
#        'SOURCEMETH', 'SOURCECLAS', 'AGENCYACRE', 'ACREAGEMET', 'COMMENTS',
#        'FIREID', 'FIREYEAR', 'UPDATETIME', 'UPDATEUSER', 'USEDONFINA',
#        'FPOUTDATE', 'FPMERGEDDA', 'IRWINID', 'PRESCRIBED', 'FIRESEASON',
#        'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
canada_gdf.columns
# Out:
# Index(['YEAR', 'NFIREID', 'BASRC', 'FIREMAPS', 'FIREMAPM', 'FIRECAUS',
#        'BURNCLAS', 'SDATE', 'EDATE', 'AFSDATE', 'AFEDATE', 'CAPDATE',
#        'POLY_HA', 'ADJ_HA', 'ADJ_FLAG', 'AGENCY', 'BT_GID', 'VERSION',
#        'COMMENTS', 'geometry'],
#       dtype='object')

# %%
test_dob = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/DAAC/ABoVE_DoB_2001/ABoVE_DoB_2001.shp')
test_dob.head()
# Out:
#    UID_Fire FD_Agency REF_ID date_src  Year   JD    Map_Date  \
# 0        10        AK     97       FD  2001  176  2001-06-25
# 1        13        AK     59       FD  2001  147  2001-05-27
# 2        14        AK     12       FD  2001  129  2001-05-09
# 3        15        AK    109       FD  2001  180  2001-06-29
# 4        17        AK    107       FD  2001  179  2001-06-28
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-2547566.445 3962899.675 0.0...
# 1  POLYGON Z ((-4378947.001 4372795.733 0.000, -4...
# 2  POLYGON Z ((-2204901.610 3511974.979 0.000, -2...
# 3  POLYGON Z ((-2135124.267 3377350.552 0.000, -2...
# 4  POLYGON Z ((-2621190.128 3404175.090 0.000, -2...

# %%
test_fire = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/AK_CA_scars/2016_AK_scars.shp')
test_fire.head()
# Out:
#    OBJECTID            NAME RECORDNUMB   ACRES AFSNUMBER DOFNUMBER USFSNUMBER  \
# 0      1588         Sunrise        102    27.5      J8TQ    601102       None
# 1      2473         Mariner        290   748.5      KA5P    631290       None
# 2      2474      Mooseheart        330     4.5      KB7Q    631330       None
# 3      2475  Zitziana River        332     1.7      KB7S    631332       None
# 4      2476   Paradise Fork        477  1147.2      KF07      None       None
#
#   ADDNUMBER  PERIMETERD LATESTPERI  ...     UPDATEUSER USEDONFINA   FPOUTDATE  \
# 0      None  2016-05-10        Yes  ...  DNR MS-Palmer        Yes  2016-05-17
# 1       730  2016-06-27        Yes  ...       mstoeber         No  2016-07-26
# 2         1  2016-06-28        Yes  ...       mstoeber         No  2016-07-30
# 3       0.1  2016-06-28        Yes  ...       mstoeber         No  2016-07-30
# 4     905.2  2016-07-16        Yes  ...       mstoeber         No  2016-08-08
#
# ...

# %%
len(alaska_gdf.columns)
# Out:
# 29

# %%
test_boundary = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/Geometries/Alaska_Canada_Area/Canada_and_Alaska.shp')
test_boundary.head()
# Out:
#      Name  ID                                           geometry
# 0  Alaska   0  MULTIPOLYGON (((-156.54666 71.30525, -156.4402...
# 1  Canada   1  MULTIPOLYGON (((-84.47945 77.29443, -84.46764 ...

# %%
test_boundary = test_boundary.to_crs('ESRI:102001')
test_boundary.crs
# Out:
# <Derived Projected CRS: ESRI:102001>
# Name: Canada_Albers_Equal_Area_Conic
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.
# - bounds: (-141.01, 38.21, -40.73, 86.46)
# Coordinate Operation:
# - name: Canada_Albers_Equal_Area_Conic
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
test_boundary.to_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/Geometries/Alaska_Canada_Area/Canada_and_Alaska_Canada_Albers.gpkg')

# %%
test_scar_db = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/scars_vs_fires/FD/2001_NA_FD_proj.shp')
test_scar_db.head()
# Out:
#        FireName FireYear  CalcAcres   PerimDate         PerimTime  AgencyAcre  \
# 0  Herron River     2001     6247.8  2008-04-25  2008/04/25 13:00         0.0
# 1          None     2001        9.9  2001-11-01  2001/11/01 09:00         0.0
# 2     Hillbilly     2001     1475.2  2004-11-23  2004/11/23 09:00         0.0
# 3          None     2001     3259.2  2004-11-23  2004/11/23 09:00         0.0
# 4   Survey Line     2001   112106.8  2004-11-23  2004/11/23 09:00         0.0
#
#   Method SrcMethod SrcClass    EditDate  ... MORE_INFO  CFS_REF_ID CFS_HA  \
# 0   None      None     None  2008-04-25  ...      None        None    0.0
# 1   None      None     None  2010-02-25  ...      None        None    0.0
# 2   None      None     None  2004-11-23  ...      None        None    0.0
# 3   None      None     None  2004-11-23  ...      None        None    0.0
# 4   None      None     None  2004-11-23  ...      None        None    0.0
#
# ...

# %%
test_canada_scar_db = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/Fire_Perimeters/CanadaFireDatabase_FireHistory/CNFDB/NFDB_poly_20170928.shp')
test_canada_scar_db.head()
# Out:
#   SRC_AGENCY      FIRE_ID FIRENAME  YEAR  MONTH  DAY    REP_DATE    DATE_TYPE  \
# 0         BC  2004-C10175     None  2004      6   23  2004-06-23  Report date
# 1         BC  2004-C10176     None  2004      6   23  2004-06-23  Report date
# 2         BC  2004-C50114     None  2004      6   20  2004-06-20  Report date
# 3         BC  2004-C50125     None  2004      6   21  2004-06-21  Report date
# 4         BC  2004-C50149     None  2004      6   22  2004-06-22  Report date
#
#       DECADE  SIZE_HA  ...     CFS_HA CFS_NOTE CFS_NOTE2    ACQ_DATE  \
# 0  2000-2009   1370.5  ...   1370.507     None      None  2011-06-10
# 1  2000-2009    520.7  ...    520.796     None      None  2011-06-10
# 2  2000-2009    268.2  ...    268.291     None      None  2011-06-10
# 3  2000-2009  20506.4  ...  20506.415     None      None  2011-06-10
# 4  2000-2009   2408.5  ...   2408.587     None      None  2011-06-10
#
#    AG_SRCFILE  POLY_DATE OUTDATE  LAT LONG  \
# ...

# %%
canada_gdf.head()
# Out:
#      YEAR  NFIREID  BASRC  FIREMAPS  FIREMAPM  FIRECAUS  BURNCLAS SDATE EDATE  \
# 0  1986.0    208.0    1.0       9.0       7.0       2.0       4.0  None  None
# 1  1986.0     31.0    1.0       9.0       7.0       4.0       4.0  None  None
# 2  1986.0    159.0    3.0       0.0       2.0       4.0       4.0  None  None
# 3  1986.0    102.0    3.0       0.0       2.0       4.0       4.0  None  None
# 4  1986.0     13.0    1.0       9.0       7.0       2.0       4.0  None  None
#
#       AFSDATE AFEDATE     CAPDATE      POLY_HA       ADJ_HA  ADJ_FLAG AGENCY  \
# 0  1986-07-10    None  1986-09-12  3408.092664  3408.092664       0.0     NT
# 1  1986-05-14    None  1986-06-20  2767.768044  2767.768044       0.0     NB
# 2  1986-05-28    None        None    49.268235    53.316641       2.0     BC
# 3  1986-10-20    None        None     6.743968     7.880180       2.0     BC
# 4  1986-05-27    None  1986-07-30  1882.734463  1882.734463       0.0     QC
#
#    BT_GID           VERSION  \
# ...

# %%
test_canada_scar_db.columns
# Out:
# Index(['SRC_AGENCY', 'FIRE_ID', 'FIRENAME', 'YEAR', 'MONTH', 'DAY', 'REP_DATE',
#        'DATE_TYPE', 'DECADE', 'SIZE_HA', 'CAUSE', 'SOURCE', 'METHOD',
#        'MORE_INFO', 'CFS_REF_ID', 'CFS_HA', 'CFS_NOTE', 'CFS_NOTE2',
#        'ACQ_DATE', 'AG_SRCFILE', 'POLY_DATE', 'OUTDATE', 'LAT', 'LONG',
#        'geometry'],
#       dtype='object')

# %%
canada_gdf.columns
# Out:
# Index(['YEAR', 'NFIREID', 'BASRC', 'FIREMAPS', 'FIREMAPM', 'FIRECAUS',
#        'BURNCLAS', 'SDATE', 'EDATE', 'AFSDATE', 'AFEDATE', 'CAPDATE',
#        'POLY_HA', 'ADJ_HA', 'ADJ_FLAG', 'AGENCY', 'BT_GID', 'VERSION',
#        'COMMENTS', 'geometry'],
#       dtype='object')

# %%
alaska_gdf.columns
# Out:
# Index(['OBJECTID', 'NAME', 'RECORDNUMB', 'ACRES', 'AFSNUMBER', 'DOFNUMBER',
#        'USFSNUMBER', 'ADDNUMBER', 'PERIMETERD', 'LATESTPERI', 'SOURCE',
#        'SOURCEMETH', 'SOURCECLAS', 'AGENCYACRE', 'ACREAGEMET', 'COMMENTS',
#        'FIREID', 'FIREYEAR', 'UPDATETIME', 'UPDATEUSER', 'USEDONFINA',
#        'FPOUTDATE', 'FPMERGEDDA', 'IRWINID', 'PRESCRIBED', 'FIRESEASON',
#        'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
canada_gdf['NFIREID'].unique(), test_canada_scar_db['FIRE_ID'].unique(), alaska_gdf['FIREID'].unique()
# Out:
# (array([ 208.,   31.,  159., ..., 4150., 4136., 4176.]),
#  array(['2004-C10175', '2004-C10176', '2004-C50114', ..., '15-070-2015',
#         '15-073-2015', '16-004-2015'], dtype=object),
#  array([68718, 69485, 68822, ..., 27779, 27778, 32074]))

# %%
last_test = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/scars_vs_fires/join_continuous_V2/scars/2001_FD_AF_join_buff2.shp')
last_test.head()
# Out:
#    Join_Count  TARGET_FID  JOIN_FID  YYYYMMDD  HHMM sat     lat      lon  \
# 0           1        4683       732  20010523  1921   T  53.001 -118.068
# 1           1        4703        57  20010705  1901   T  52.596 -116.042
# 2           1        4706        23  20010706   612   T  50.132 -115.554
# 3           1        4712        26  20010711   453   T  52.041 -117.635
# 4           1        4713        26  20010711   453   T  52.029 -117.678
#
#      T21    T31  sample    FRP  conf  type YYYYMMDD_s  MON  UID_Fire  \
# 0  337.0  308.0     775   33.1    68     0   20010523    5       745
# 1  311.5  299.8     614    7.3    53     0   20010705    7        58
# 2  303.3  285.0     222   17.9    54     0   20010706    7        24
# 3  304.4  290.5    1270   36.4    20     0   20010711    7        27
# 4  338.1  295.4    1271  200.3   100     0   20010711    7        27
#
#    BUFF_DIST  ORIG_FID                          geometry
# ...

# %%
nextstep = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/AK_CA_scars/merged/proj_clean/2016_NA_FD_proj.shp')
nextstep.head()
# Out:
#    PERIMETERD REP_DATE  UID_Fire  \
# 0  2016-05-10     None         1
# 1  2016-06-27     None         2
# 2  2016-06-28     None         3
# 3  2016-06-28     None         4
# 4  2016-07-16     None         5
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-2510344.098 3466512.386 0.0...
# 1  POLYGON Z ((-2000595.885 3396966.901 0.000, -2...
# 2  POLYGON Z ((-2319946.619 3760482.138 0.000, -2...
# 3  POLYGON Z ((-2305984.045 3743785.242 0.000, -2...
# 4  POLYGON Z ((-2453237.854 3783560.149 0.000, -2...

# %%
nextstep['UID_Fire'].max()
# Out:
# 1177

# %%
nextstep = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/AK_CA_scars/merged/proj_clean/2017_NA_FD_proj.shp')
nextstep.head()
# Out:
#    PERIMETERD REP_DATE  UID_Fire  \
# 0  2017-06-05     None         1
# 1  2017-06-26     None         2
# 2  2017-06-15     None         3
# 3  2017-06-12     None         4
# 4  2017-06-12     None         5
#
#                                             geometry
# 0  POLYGON Z ((-2839909.234 3983055.516 0.000, -2...
# 1  POLYGON Z ((-2834194.254 3728944.532 0.000, -2...
# 2  POLYGON Z ((-2845656.455 4076409.396 0.000, -2...
# 3  POLYGON Z ((-2596469.956 3701172.665 0.000, -2...
# 4  POLYGON Z ((-2625010.094 3851847.031 0.000, -2...

# %%
nextstep['UID_Fire'].max()
# Out:
# 1719

# %%
nextstep = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/AK_CA_scars/merged/proj_clean/2018_NA_FD_proj.shp')
nextstep.head()
# Out:
#    PERIMETERD REP_DATE  UID_Fire  \
# 0  2018-07-26     None         1
# 1  2018-06-24     None         2
# 2  2018-06-06     None         3
# 3  2018-06-06     None         4
# 4  2018-06-08     None         5
#
#                                             geometry
# 0  POLYGON Z ((-2358591.280 4048404.269 0.000, -2...
# 1  POLYGON Z ((-2594383.112 3887242.971 0.000, -2...
# 2  POLYGON Z ((-2659839.754 3716122.681 0.000, -2...
# 3  POLYGON Z ((-2753892.942 3690477.652 0.000, -2...
# 4  POLYGON Z ((-2586461.262 3704366.927 0.000, -2...

# %%
nextstep['UID_Fire'].max()
# Out:
# 1955

# %% [markdown]
# ## Testing the merge of databases

# %%
alaska_filename = '/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/DAAC_Update_2023/Fire_Perimeters/ALFD_1940_2022/ALFD_1940_2022.shp'
canada_filename = '/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/DAAC_Update_2023/Fire_Perimeters/NBAC_1986_2022/nbac_1986_to_2022_20230630.shp'

# %%
alaska_gdf = gpd.read_file(alaska_filename)
alaska_gdf.head(1)
# Out:
#    OBJECTID         NAME RECORDNUMB    ACRES AFSNUMBER DOFNUMBER USFSNUMBER  \
# 0         1  2022 MID Rx       2200  1467.14      None  73234001       None
#
#   ADDNUMBER  PERIMETERD LATESTPERI  ... UPDATEUSER USEDONFINA   FPOUTDATE  \
# 0      2008  2022-11-22        Yes  ...   dmgriggs       None  2022-09-19
#
#    FPMERGEDDA                                 IRWINID PRESCRIBED   FIRESEASON  \
# 0        None  {359E7604-4270-438A-B9C4-BCC054F8D315}          Y  2020 - 2029
#
#      Shape_Leng    Shape_Area  \
# 0  68593.094416  5.937317e+06
#
#                                             geometry
# 0  MULTIPOLYGON (((410437.096 1577351.557, 410459...
#
# [1 rows x 29 columns]

# %%
canada_gdf = gpd.read_file(canada_filename)
canada_gdf.head(1)
# Out:
#      YEAR  NFIREID  BASRC  FIREMAPS  FIREMAPM  FIRECAUS  BURNCLAS SDATE EDATE  \
# 0  1986.0    208.0    1.0       9.0       7.0       2.0       4.0  None  None
#
#       AFSDATE AFEDATE     CAPDATE      POLY_HA       ADJ_HA  ADJ_FLAG AGENCY  \
# 0  1986-07-10    None  1986-09-12  3408.092664  3408.092664       0.0     NT
#
#    BT_GID           VERSION COMMENTS  \
# 0    12.0  1986_r9_20210810     Null
#
#                                             geometry
# 0  POLYGON ((-1409877.875 1922967.375, -1409851.5...

# %%
alaska_gdf.crs
# Out:
# <Derived Projected CRS: EPSG:3338>
# Name: NAD83 / Alaska Albers
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Alaska.
# - bounds: (172.42, 51.3, -129.99, 71.4)
# Coordinate Operation:
# - name: Alaska Albers (meters)
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
canada_gdf.crs
# Out:
# <Derived Projected CRS: PROJCS["Canada_Lambert_Conformal_Conic",GEOGCS["NA ...>
# Name: Canada_Lambert_Conformal_Conic
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
alaska_gdf = alaska_gdf.to_crs('ESRI:102001')
canada_gdf = canada_gdf.to_crs('ESRI:102001')

# %%
alaska_gdf.columns, canada_gdf.columns
# Out:
# (Index(['OBJECTID', 'NAME', 'RECORDNUMB', 'ACRES', 'AFSNUMBER', 'DOFNUMBER',
#         'USFSNUMBER', 'ADDNUMBER', 'PERIMETERD', 'LATESTPERI', 'SOURCE',
#         'SOURCEMETH', 'SOURCECLAS', 'AGENCYACRE', 'ACREAGEMET', 'COMMENTS',
#         'FIREID', 'FIREYEAR', 'UPDATETIME', 'UPDATEUSER', 'USEDONFINA',
#         'FPOUTDATE', 'FPMERGEDDA', 'IRWINID', 'PRESCRIBED', 'FIRESEASON',
#         'Shape_Leng', 'Shape_Area', 'geometry'],
#        dtype='object'),
#  Index(['YEAR', 'NFIREID', 'BASRC', 'FIREMAPS', 'FIREMAPM', 'FIRECAUS',
#         'BURNCLAS', 'SDATE', 'EDATE', 'AFSDATE', 'AFEDATE', 'CAPDATE',
#         'POLY_HA', 'ADJ_HA', 'ADJ_FLAG', 'AGENCY', 'BT_GID', 'VERSION',
#         'COMMENTS', 'geometry'],
#        dtype='object'))

# %%
final_gdf = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/ABoVE_DoB/Version2.0_2016_2019_update/AK_CA_scars/merged/proj_clean/2018_NA_FD_proj.shp')
final_gdf.head()
# Out:
#    PERIMETERD REP_DATE  UID_Fire  \
# 0  2018-07-26     None         1
# 1  2018-06-24     None         2
# 2  2018-06-06     None         3
# 3  2018-06-06     None         4
# 4  2018-06-08     None         5
#
#                                             geometry
# 0  POLYGON Z ((-2358591.280 4048404.269 0.000, -2...
# 1  POLYGON Z ((-2594383.112 3887242.971 0.000, -2...
# 2  POLYGON Z ((-2659839.754 3716122.681 0.000, -2...
# 3  POLYGON Z ((-2753892.942 3690477.652 0.000, -2...
# 4  POLYGON Z ((-2586461.262 3704366.927 0.000, -2...

# %%
final_gdf.PERIMETERD.unique()
# Out:
# array(['2018-07-26', '2018-06-24', '2018-06-06', '2018-06-08',
#        '2018-07-07', '2018-07-23', '2018-06-15', '2018-06-11',
#        '2018-06-12', '2018-06-21', '2018-06-14', '2018-07-05',
#        '2018-06-09', '2018-07-03', '2018-06-26', '2018-06-07',
#        '2018-07-02', '2018-06-25', '2018-07-08', '2018-05-30',
#        '2018-06-13', '2018-07-24', '2018-06-01', '2018-05-18',
#        '2018-05-15', '2018-07-14', '2018-05-25', '2018-06-10',
#        '2018-06-04', '2018-06-05', '2018-06-20', '2018-06-19',
#        '2018-02-19', '2018-05-14', '2018-09-17', '2018-08-03',
#        '2018-08-31', '2018-08-10', '2018-08-13', '2018-08-12',
#        '2018-09-09', '2018-09-07', '2018-07-31', '2018-09-13', None],
#       dtype=object)

# %%
alaska_gdf = alaska_gdf[['PERIMETERD', 'FIREYEAR', 'geometry']]
alaska_gdf.head(1)
# Out:
#    PERIMETERD FIREYEAR                                           geometry
# 0  2022-11-22     2022  MULTIPOLYGON (((-2186447.489 3509475.166, -218...

# %%
canada_gdf = canada_gdf[['SDATE', 'EDATE', 'AFSDATE', 'AFEDATE', 'CAPDATE', 'YEAR', 'geometry']].rename(columns={'YEAR': 'FIREYEAR'})
canada_gdf.head(1)
# Out:
#   SDATE EDATE     AFSDATE AFEDATE     CAPDATE  FIREYEAR  \
# 0  None  None  1986-07-10    None  1986-09-12    1986.0
#
#                                             geometry
# 0  POLYGON ((-1394310.237 2921922.977, -1394282.9...

# %%
canada_gdf['FIREYEAR'] = canada_gdf['FIREYEAR'].astype(int)
alaska_gdf['FIREYEAR'] = alaska_gdf['FIREYEAR'].astype(int)
canada_gdf.head(1)
# Out:
#   SDATE EDATE     AFSDATE AFEDATE     CAPDATE  FIREYEAR  \
# 0  None  None  1986-07-10    None  1986-09-12      1986
#
#                                             geometry
# 0  POLYGON ((-1394310.237 2921922.977, -1394282.9...

# %%
fp_gdf = pd.concat([alaska_gdf, canada_gdf], axis=0)
fp_gdf.head()
# Out:
#    PERIMETERD  FIREYEAR                                           geometry  \
# 0  2022-11-22      2022  MULTIPOLYGON (((-2186447.489 3509475.166, -218...
# 1  2022-11-10      2022  MULTIPOLYGON (((-2181582.390 3505940.968, -218...
# 2  2022-11-01      2022  MULTIPOLYGON (((-2203487.518 3540562.571, -220...
# 3  2022-10-31      2022  POLYGON ((-2140547.714 3377246.006, -2140530.0...
# 4  2022-09-21      2022  POLYGON ((-1830817.638 3620409.868, -1830781.3...
#
#   SDATE EDATE AFSDATE AFEDATE CAPDATE
# 0   NaN   NaN     NaN     NaN     NaN
# 1   NaN   NaN     NaN     NaN     NaN
# 2   NaN   NaN     NaN     NaN     NaN
# 3   NaN   NaN     NaN     NaN     NaN
# 4   NaN   NaN     NaN     NaN     NaN

# %%
fp_gdf.head(-5)
# Out:
#        PERIMETERD  FIREYEAR  \
# 0      2022-11-22      2022
# 1      2022-11-10      2022
# 2      2022-11-01      2022
# 3      2022-10-31      2022
# 4      2022-09-21      2022
# ...           ...       ...
# 38246         NaN      2022
# 38247         NaN      2022
# 38248         NaN      2022
# 38249         NaN      2022
# 38250         NaN      2022
#
#                                                 geometry       SDATE  \
# 0      MULTIPOLYGON (((-2186447.489 3509475.166, -218...         NaN
# 1      MULTIPOLYGON (((-2181582.390 3505940.968, -218...         NaN
# 2      MULTIPOLYGON (((-2203487.518 3540562.571, -220...         NaN
# 3      POLYGON ((-2140547.714 3377246.006, -2140530.0...         NaN
# 4      POLYGON ((-1830817.638 3620409.868, -1830781.3...         NaN
# ...                                                  ...         ...
# 38246  POLYGON ((-989484.455 2205592.409, -989489.512...  2022-10-02
# ...

# %%
fp_gdf.shape
# Out:
# (43156, 5)

# %%
fp_gdf.FIREYEAR.unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001,
#        2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990,
#        1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979,
#        1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968,
#        1967, 1966, 1965, 1963, 1962, 1960, 1959, 1958, 1957, 1956, 1955,
#        1954, 1953, 1952, 1951, 1950, 1948, 1947, 1946, 1944, 1943, 1942,
#        1940])

# %%
fp_gdf = fp_gdf[fp_gdf['FIREYEAR'] >= 2001]
fp_gdf.FIREYEAR.unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001])

# %%
fp_gdf.head(-10)
# Out:
#        PERIMETERD  FIREYEAR  \
# 0      2022-11-22      2022
# 1      2022-11-10      2022
# 2      2022-11-01      2022
# 3      2022-10-31      2022
# 4      2022-09-21      2022
# ...           ...       ...
# 38241         NaN      2022
# 38242         NaN      2022
# 38243         NaN      2022
# 38244         NaN      2022
# 38245         NaN      2022
#
#                                                 geometry SDATE EDATE
# 0      MULTIPOLYGON (((-2186447.489 3509475.166, -218...   NaN   NaN
# 1      MULTIPOLYGON (((-2181582.390 3505940.968, -218...   NaN   NaN
# 2      MULTIPOLYGON (((-2203487.518 3540562.571, -220...   NaN   NaN
# 3      POLYGON ((-2140547.714 3377246.006, -2140530.0...   NaN   NaN
# 4      POLYGON ((-1830817.638 3620409.868, -1830781.3...   NaN   NaN
# ...                                                  ...   ...   ...
# 38241  POLYGON ((-1002151.790 2046546.301, -1002156.8...   NaN   NaN
# ...

# %%
fp_gdf.FIREYEAR.unique()
# Out:
# array([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012,
#        2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001,
#        2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990,
#        1989, 1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979,
#        1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968,
#        1967, 1966, 1965, 1963, 1962, 1960, 1959, 1958, 1957, 1956, 1955,
#        1954, 1953, 1952, 1951, 1950, 1948, 1947, 1946, 1944, 1943, 1942,
#        1940])

# %%
canada_gdf_years = canada_gdf[(canada_gdf['FIREYEAR'] >= 2001) & (canada_gdf['FIREYEAR'] <= 2022)]
canada_gdf_years.head()
# Out:
#            SDATE       EDATE     AFSDATE AFEDATE     CAPDATE  FIREYEAR  \
# 9901  2001-07-14  2001-07-14  2001-07-26    None  2001-09-17      2001
# 9902  2001-06-21  2001-07-04  2001-06-24    None  2001-09-17      2001
# 9903  2001-07-10  2001-07-10  2001-07-05    None        None      2001
# 9904  2001-05-26  2001-05-26        None    None  2001-05-27      2001
# 9905  2001-05-26  2001-05-26        None    None        None      2001
#
#                                                geometry
# 9901  MULTIPOLYGON (((-642050.112 2328754.354, -6420...
# 9902  MULTIPOLYGON (((-639762.040 2378563.067, -6397...
# 9903  MULTIPOLYGON (((-886204.504 2168407.197, -8862...
# 9904  POLYGON ((-1283054.600 2307580.406, -1283054.5...
# 9905  POLYGON ((-1112191.665 2038621.910, -1112191.6...

# %%
nfd_gdf = gpd.read_file('/explore/nobackup/projects/ilab/projects/LobodaTFO/data/Fire_Perimeters/CanadaFireDatabase_FireHistory/CNFDB/NFDB_poly_20170928.shp')
nfd_gdf.head()
# Out:
#   SRC_AGENCY      FIRE_ID FIRENAME  YEAR  MONTH  DAY    REP_DATE    DATE_TYPE  \
# 0         BC  2004-C10175     None  2004      6   23  2004-06-23  Report date
# 1         BC  2004-C10176     None  2004      6   23  2004-06-23  Report date
# 2         BC  2004-C50114     None  2004      6   20  2004-06-20  Report date
# 3         BC  2004-C50125     None  2004      6   21  2004-06-21  Report date
# 4         BC  2004-C50149     None  2004      6   22  2004-06-22  Report date
#
#       DECADE  SIZE_HA  ...     CFS_HA CFS_NOTE CFS_NOTE2    ACQ_DATE  \
# 0  2000-2009   1370.5  ...   1370.507     None      None  2011-06-10
# 1  2000-2009    520.7  ...    520.796     None      None  2011-06-10
# 2  2000-2009    268.2  ...    268.291     None      None  2011-06-10
# 3  2000-2009  20506.4  ...  20506.415     None      None  2011-06-10
# 4  2000-2009   2408.5  ...   2408.587     None      None  2011-06-10
#
#    AG_SRCFILE  POLY_DATE OUTDATE  LAT LONG  \
# ...

# %%
nfd_gdf_years = nfd_gdf[(nfd_gdf['YEAR'] >= 2001) & (nfd_gdf['YEAR'] <= 2022)]
nfd_gdf_years.head()
# Out:
#   SRC_AGENCY      FIRE_ID FIRENAME  YEAR  MONTH  DAY    REP_DATE    DATE_TYPE  \
# 0         BC  2004-C10175     None  2004      6   23  2004-06-23  Report date
# 1         BC  2004-C10176     None  2004      6   23  2004-06-23  Report date
# 2         BC  2004-C50114     None  2004      6   20  2004-06-20  Report date
# 3         BC  2004-C50125     None  2004      6   21  2004-06-21  Report date
# 4         BC  2004-C50149     None  2004      6   22  2004-06-22  Report date
#
#       DECADE  SIZE_HA  ...     CFS_HA CFS_NOTE CFS_NOTE2    ACQ_DATE  \
# 0  2000-2009   1370.5  ...   1370.507     None      None  2011-06-10
# 1  2000-2009    520.7  ...    520.796     None      None  2011-06-10
# 2  2000-2009    268.2  ...    268.291     None      None  2011-06-10
# 3  2000-2009  20506.4  ...  20506.415     None      None  2011-06-10
# 4  2000-2009   2408.5  ...   2408.587     None      None  2011-06-10
#
#    AG_SRCFILE  POLY_DATE OUTDATE  LAT LONG  \
# ...

# %%
nfd_gdf_years['YEAR'].value_counts().sort_index()
# Out:
# 2001     797
# 2002     865
# 2003    1201
# 2004     813
# 2005     868
# 2006    1522
# 2007    1139
# 2008    1261
# 2009    1220
# 2010    1625
# 2011     903
# 2012    1466
# 2013    1481
# 2014    1189
# 2015    1819
# 2016    1018
# Name: YEAR, dtype: int64

# %%
canada_gdf_years['FIREYEAR'].value_counts().sort_index()
# Out:
# 2001     798
# 2002     848
# 2003    1154
# 2004     879
# 2005    1128
# 2006    1598
# 2007    1201
# 2008    1269
# 2009    1246
# 2010    1628
# 2011     958
# 2012    1511
# 2013    1637
# 2014    1410
# 2015    2173
# 2016    1002
# 2017    1525
# 2018    1749
# 2019     892
# 2020     657
# 2021    1753
# 2022    1339
# Name: FIREYEAR, dtype: int64
